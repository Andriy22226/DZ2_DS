# %%
Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
# %matplotlib inline
import pandas as pd
df = pd.read_csv('./2017_jun_final.csv')

# %%
Прочитайте отриману таблицю, використовуючи метод head

# %%
df.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# ...

# %%
#изначте розмір таблиці за допомогою методу shape

# %%
print(f"кількість рядків та стовпців:{df.shape}")
# Out:
# кількість рядків та стовпців:(8704, 25)

# %%
Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
print(df.dtypes)
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
#Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
print("Частка пропусків в кожній колонці:")
print(missing_percentage)
# Out:
# Частка пропусків в кожній колонці:
# N                                    0.000000
# Должность                            0.000000
# Язык.программирования               44.232537
# Специализация                       82.938879
# Общий.опыт.работы                    0.000000
# Опыт.работы.на.текущем.месте         0.000000
# Зарплата.в.месяц                     0.000000
# Изменение.зарплаты.за.12.месяцев     0.000000
# Город                                0.000000
# Размер.компании                      0.000000
# Тип.компании                         0.000000
# Пол                                  0.000000
# Возраст                              0.000000
# Образование                          0.000000
# Университет                          4.113051
# Еще.студент                          0.000000
# Уровень.английского                  0.000000
# Предметная.область                   2.562040
# Дата.заполнения                      0.000000
# User.Agent                           0.000000
# ...

# %%
Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
columns_with_na = df.columns[df.isna().any()]
columns_to_keep = ['Язык.программирования']
columns_to_drop = [col for col in columns_with_na if col not in columns_to_keep]
df = df.drop(columns=columns_to_drop)

# %%
Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
print("Частка пропусків в кожній колонці:")
print(missing_percentage)
# Out:
# Частка пропусків в кожній колонці:
# N                                    0.000000
# Должность                            0.000000
# Язык.программирования               44.232537
# Общий.опыт.работы                    0.000000
# Опыт.работы.на.текущем.месте         0.000000
# Зарплата.в.месяц                     0.000000
# Изменение.зарплаты.за.12.месяцев     0.000000
# Город                                0.000000
# Размер.компании                      0.000000
# Тип.компании                         0.000000
# Пол                                  0.000000
# Возраст                              0.000000
# Образование                          0.000000
# Еще.студент                          0.000000
# Уровень.английского                  0.000000
# Дата.заполнения                      0.000000
# User.Agent                           0.000000
# exp                                  0.000000
# current_job_exp                      0.000000
# salary                               0.000000
# ...

# %%
Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
df.dropna(inplace=True)

# %%
Визначте новий розмір таблиці за допомогою методу shape

# %%
new_shape = df.shape
print("Новий розмір таблиці після видалення рядків з пропусками:", new_shape)
# Out:
# Новий розмір таблиці після видалення рядків з пропусками: (4854, 20)

# %%
Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data = df[df['Язык.программирования'].str.contains('Python', case=False, na=False)]
python_data.head()
# Out:
#        N                 Должность Язык.программирования Общий.опыт.работы  \
# 12    13         Software Engineer                Python                 1
# 68    69         Software Engineer                Python               1.5
# 87    88  Junior Software Engineer                Python               0.5
# 114  115  Junior Software Engineer                Python               1.5
# 143  144  Junior Software Engineer                Python                 1
#
#     Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 12              меньше 3 месяцев               800
# 68                           0.5               900
# 87                           0.5               600
# 114                          0.5               685
# 143                            1               750
#
#      Изменение.зарплаты.за.12.месяцев Город  Размер.компании    Тип.компании  \
# 12                                200  Киев    до 50 человек  Аутсорсинговая
# ...

# %%
Визначте розмір таблиці python_data за допомогою методу shape

# %%
print("Новий розмір таблиці python_data:", python_data.shape)
# Out:
# Новий розмір таблиці python_data: (207, 20)

# %%
Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
grouped_by_position = df.groupby('Должность')

# %%
#Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада",
#виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
aggregated_data = grouped_by_position.agg({'Зарплата.в.месяц': ['min', 'max']})
aggregated_data.columns = ['Мінімальна_зарплата', 'Максимальна_зарплата']

print(aggregated_data)
# Out:
#                                Мінімальна_зарплата  Максимальна_зарплата
# Должность
# Data Scientist / Data Analyst                 2700                  2700
# DevOps                                        7000                  7000
# ERP / CRM                                     2000                  2000
# HTML coder                                     385                   600
# Junior Software Engineer                        75                  2600
# Product Manager                               3000                  3000
# Senior Software Engineer                       350                  9200
# Software Engineer                              100                  7000
# System Architect                               400                 10000
# Team lead                                     2500                  4000
# Technical Lead                                 500                 18000

# %%
import matplotlib.pyplot as plt

min_salary = aggregated_data['Мінімальна_зарплата']
max_salary = aggregated_data['Максимальна_зарплата']

max_height = max(7, 0)

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.hist(min_salary, bins=15, edgecolor='k', alpha=0.7, color='#f748ce')
plt.title('Гістограма мінімальних зарплат')
plt.xlabel('Мінімальна зарплата')
plt.ylabel('Кількість посад')
plt.ylim(0, max_height)

plt.subplot(1, 2, 2)
plt.hist(max_salary, bins=15, edgecolor='k', alpha=0.7, color='#1df0d0')
plt.title('Гістограма максимальних зарплат')
plt.xlabel('Максимальна зарплата')
plt.ylabel('Кількість посад')
plt.ylim(0, max_height)

plt.tight_layout()
plt.show()

# %%
Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць.
Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
def fill_avg_salary(row):
    avg_salary = row['Зарплата.в.месяц'] + row['Изменение.зарплаты.за.12.месяцев'] / 12
    row['avg'] = avg_salary
    return row

python_data = python_data.apply(fill_avg_salary, axis=1)
python_data.head()
# Out:
#        N                 Должность Язык.программирования Общий.опыт.работы  \
# 12    13         Software Engineer                Python                 1
# 68    69         Software Engineer                Python               1.5
# 87    88  Junior Software Engineer                Python               0.5
# 114  115  Junior Software Engineer                Python               1.5
# 143  144  Junior Software Engineer                Python                 1
#
#     Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 12              меньше 3 месяцев               800
# 68                           0.5               900
# 87                           0.5               600
# 114                          0.5               685
# 143                            1               750
#
#      Изменение.зарплаты.за.12.месяцев Город  Размер.компании    Тип.компании  \
# 12                                200  Киев    до 50 человек  Аутсорсинговая
# ...

# %%
#Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
avg_salary_stats = python_data['avg'].describe()
print(avg_salary_stats)
# Out:
# count     207.000000
# mean     1785.246779
# std      1327.988273
# min       100.000000
# 25%       754.166667
# 50%      1491.666667
# 75%      2508.333333
# max      9383.333333
# Name: avg, dtype: float64

# %%
Збережіть отриману таблицю в CSV файл

# %%
python_data.to_csv('./new_data_file.csv', index=False)

# %%
type_counts = python_data['Тип.компании'].value_counts()

explode = [0, 0, 0.15, 0, 0]
plt.figure(figsize=(10, 10))
plt.pie(type_counts, shadow=True, labels=type_counts.index, explode=explode, autopct='%1.1f%%', pctdistance=1.1,
    labeldistance=1.2)
plt.title('Відсоток респондентів за Типом компанії', y=1.05)
plt.axis('equal')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(40, 20))
ax = fig.add_subplot(projection='3d')

x = df['Должность']
y = df['Зарплата.в.месяц'].astype(float)

df['Общий.опыт.работы'] = df['Общий.опыт.работы'].replace('10 и более лет', '10')
df['Общий.опыт.работы'] = df['Общий.опыт.работы'].replace('меньше 3 месяцев', '0')
df['Общий.опыт.работы'] = pd.to_numeric(df['Общий.опыт.работы'])
z = df['Общий.опыт.работы'].astype(float)

positions = df['Должность'].unique()
position_ids = range(len(positions))
colors = {'Data Scientist / Data Analyst': 'r', 'DevOps': 'b', 'ERP / CRM': 'g', 'HTML coder': 'y',
          'Junior Software Engineer': 'c', 'Product Manager': 'm', 'Senior Software Engineer': 'y',
          'Software Engineer': 'k', 'System Architect': 'b', 'Team lead': 'g', 'Technical Lead': 'r'}

size = 40

for position_id, position in zip(position_ids, positions):
    subset = df[df['Должность'] == position]
    ax.scatter([position_id] * len(subset), subset['Зарплата.в.месяц'], subset['Общий.опыт.работы'],
               c=colors[position], s=size, label=position)

ax.set_xlabel('Посада', color='midnightblue')
ax.set_xticks(position_ids)
ax.set_xticklabels(positions, rotation=45, ha='center', fontsize=10)
ax.set_ylabel('Зарплата.в.месяц', color='midnightblue')
ax.set_zlabel('Общий.опыт.работы', color='midnightblue')
ax.legend(loc='upper right', prop={'size': 12})
plt.show()

# %%
['Software Engineer' 'Senior Software Engineer' 'Junior Software Engineer'
 'System Architect' 'Technical Lead' 'Data Scientist / Data Analyst'
 'HTML coder' 'DevOps' 'Product Manager' 'Team lead' 'ERP / CRM']
